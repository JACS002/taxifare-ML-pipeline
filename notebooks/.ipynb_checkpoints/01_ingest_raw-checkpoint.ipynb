# %%
import os, sys, time
from datetime import datetime
from pyspark.sql import SparkSession, functions as F, types as T

PG_HOST = os.getenv("PG_HOST", "postgres")
PG_PORT = os.getenv("PG_PORT", "5432")
PG_DB   = os.getenv("PG_DB", "nyc_taxi")
PG_USER = os.getenv("PG_USER", "postgres")
PG_PASS = os.getenv("PG_PASSWORD", "postgres")
SCHEMA_RAW = os.getenv("PG_SCHEMA_RAW", "raw")

YEARS_ENV   = os.getenv("YEARS", "2015-2025")
SERVICES    = [s.strip() for s in os.getenv("SERVICES","yellow,green").split(",")]
RUN_ID      = os.getenv("RUN_ID", f"run-{int(time.time())}")

def parse_years(r):
    # "2015-2025" o "2019,2020,2021"
    if "-" in r:
        a,b = r.split("-")
        return list(range(int(a), int(b)+1))
    return [int(x) for x in r.split(",")]

YEARS = parse_years(YEARS_ENV)

JDBC_URL = f"jdbc:postgresql://{PG_HOST}:{PG_PORT}/{PG_DB}"
JDBC_OPTS = {
    "url": JDBC_URL,
    "driver": "org.postgresql.Driver",
    "user": PG_USER,
    "password": PG_PASS,
}

spark = (
    SparkSession.builder
    .appName("ingesta_raw_nyc_taxi")
    .getOrCreate()
)
spark

spark.conf.get("spark.driver.memory"), spark.conf.get("spark.executor.memory")
# Out:
# ('6g', '6g')

# %%
def common_casts(df, service):
    # Normaliza timestamps y tipos comunes según servicio
    if service == "yellow":
        pickup_col = "tpep_pickup_datetime"
        dropoff_col = "tpep_dropoff_datetime"
    else:
        pickup_col = "lpep_pickup_datetime"
        dropoff_col = "lpep_dropoff_datetime"

    # columnas que suelen estar presentes
    cols_float = [c for c in ["fare_amount","extra","mta_tax","tip_amount","tolls_amount",
                              "improvement_surcharge","total_amount","congestion_surcharge"]
                  if c in df.columns]
    for c in cols_float:
        df = df.withColumn(c, F.col(c).cast("double"))

    for c in [pickup_col, dropoff_col]:
        if c in df.columns:
            df = df.withColumn(c, F.to_timestamp(F.col(c)))

    # agrega metadatos
    df = (df
          .withColumn("ingested_at_utc", F.current_timestamp())
          .withColumn("run_id", F.lit(RUN_ID))
         )
    return df, pickup_col, dropoff_col

def write_df(df, table, mode="append"):
    (df.write.format("jdbc")
       .options(**JDBC_OPTS)
       .option("dbtable", table)
       .mode(mode)
       .save())

# %%
import pandas as pd

zones_url = "https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv"

# 1) Descargar con pandas (soporta https)
zones_pdf = pd.read_csv(zones_url)

# 2) Subir a Spark
zones = spark.createDataFrame(zones_pdf)

# 3) Tipos + metadatos
zones = (zones
         .withColumn("LocationID", F.col("LocationID").cast("int"))
         .withColumn("ingested_at_utc", F.current_timestamp())
         .withColumn("run_id", F.lit(RUN_ID)))

# 4) Guardar en Postgres
write_df(zones, f"{SCHEMA_RAW}.taxi_zone_lookup", mode="overwrite")
print("✅ raw.taxi_zone_lookup")
# Out:
# ✅ raw.taxi_zone_lookup

# %%
from pyspark.sql import functions as F, types as T

def add_missing(df, name, dtype):
    """Si la columna no existe en el DF, la agrega con NULL del tipo indicado."""
    if name not in df.columns:
        df = df.withColumn(name, F.lit(None).cast(dtype))
    return df

def align_raw_optional_columns(df, service):
    """
    Asegura que el DF tenga las columnas opcionales que existen en RAW.
    - yellow: airport_fee, cbd_congestion_fee
    - green : trip_type,  cbd_congestion_fee
    """
    if service == "yellow":
        df = add_missing(df, "airport_fee", T.DoubleType())
        df = add_missing(df, "cbd_congestion_fee", T.DoubleType())
    else:  # green
        df = add_missing(df, "trip_type", T.DoubleType())
        df = add_missing(df, "cbd_congestion_fee", T.DoubleType())
    return df

# %%
# --- Configuración: SOLO 2025 (yellow/green, meses 1..12) ---
SELECTIVE_MODE = True

SELECTIVE_MONTHS = []
for svc in ["yellow", "green"]:
    for mm in range(1, 13):
        SELECTIVE_MONTHS.append((svc, 2025, mm))

# --- Implementación: descarga temporal, ingesta y limpieza ---
import os, sys, time, traceback, subprocess
import requests
from io import BytesIO
import pandas as pd
import pyarrow.parquet as pq
from pyspark.sql import functions as F

# Asegura que exista el directorio temporal
data_tmp = "/home/jovyan/work/tmp_parquet"
os.makedirs(data_tmp, exist_ok=True)

# Si no está seteado arriba en el notebook, definimos defaults aquí:
PG_HOST = os.getenv("PG_HOST", "postgres")
PG_PORT = int(os.getenv("PG_PORT", "5432"))
PG_DB   = os.getenv("PG_DB", "nyc_taxi")
PG_USER = os.getenv("PG_USER", "postgres")
PG_PASS = os.getenv("PG_PASSWORD", "postgres")
SCHEMA_RAW = os.getenv("PG_SCHEMA_RAW", "raw")

# --- Helpers para conexión a Postgres (para pre-DELETE y schema introspection) ---
try:
    import psycopg2
except ImportError:
    subprocess.run([sys.executable, "-m", "pip", "install", "psycopg2-binary"], check=True)
    import psycopg2

def pg_exec(sql, params=None):
    conn = psycopg2.connect(
        host=PG_HOST, port=PG_PORT, dbname=PG_DB, user=PG_USER, password=PG_PASS
    )
    conn.autocommit = True
    try:
        with conn.cursor() as cur:
            cur.execute(sql, params or [])
    finally:
        conn.close()

def get_pg_columns(schema: str, table: str):
    """Lista de columnas de una tabla en Postgres (ordenadas por posición)."""
    sql = """
    SELECT column_name
    FROM information_schema.columns
    WHERE table_schema = %s AND table_name = %s
    ORDER BY ordinal_position;
    """
    conn = psycopg2.connect(
        host=PG_HOST, port=PG_PORT, dbname=PG_DB, user=PG_USER, password=PG_PASS
    )
    try:
        with conn.cursor() as cur:
            cur.execute(sql, (schema, table))
            return [r[0] for r in cur.fetchall()]
    finally:
        conn.close()

def prune_before_write(df, full_table_name: str):
    """
    Podar columnas del DataFrame que no existen en la tabla destino.
    full_table_name: 'schema.table' (p.ej. 'raw.yellow_taxi_trip')
    """
    schema, table = full_table_name.split(".")
    cols_db = set(get_pg_columns(schema, table))
    cols_df = df.columns
    keep = [c for c in cols_df if c in cols_db]
    drop = [c for c in cols_df if c not in cols_db]
    if drop:
        log(f"Podando columnas no presentes en {full_table_name}: {drop}", "WARN")
    return df.select(*keep)

def delete_partition(service, y, m):
    """Borrar la partición (service,year,month) antes de insertar (idempotencia)."""
    tbl = target_table(service)
    log(f"Pre-DELETE → {tbl} (service={service}, year={y}, month={m})", "INFO")
    pg_exec(f"DELETE FROM {tbl} WHERE service=%s AND year=%s AND month=%s;", [service, y, m])
    log("Pre-DELETE completado", "OK")

def trip_url(service, year, month):
    mm = f"{month:02d}"
    return f"https://d37ci6vzurychx.cloudfront.net/trip-data/{service}_tripdata_{year}-{mm}.parquet"

def target_table(service):
    return f"{SCHEMA_RAW}.{service}_taxi_trip"

def log(msg, level="INFO"):
    ts = time.strftime("%H:%M:%S")
    icons = {"INFO": "ℹ️", "OK": "✅", "WARN": "⚠️", "ERROR": "❌"}
    print(f"[{ts}] {icons.get(level, '')} {msg}")

# 🔧 Alinear columnas opcionales del RAW según servicio
def align_raw_optional_columns(df, service):
    """
    Garantiza columnas opcionales con tipo double y existencia consistente.
    - yellow: airport_fee, cbd_congestion_fee; trip_type = NULL (solo para homogeneidad si en tu tabla existe)
    - green : trip_type, cbd_congestion_fee;  airport_fee = NULL
    """
    def ensure_double(colname):
        nonlocal df
        if colname in df.columns:
            df = df.withColumn(colname, F.col(colname).cast("double"))
        else:
            df = df.withColumn(colname, F.lit(None).cast("double"))

    if service == "yellow":
        ensure_double("airport_fee")
        ensure_double("cbd_congestion_fee")
        # Si tu tabla raw.yellow_taxi_trip NO tiene trip_type, no lo agregues.
        # Solo descomenta estas líneas si tu tabla sí lo tiene y quieres mantener homogeneidad.
        # if "trip_type" not in df.columns:
        #     df = df.withColumn("trip_type", F.lit(None).cast("double"))
        # else:
        #     df = df.withColumn("trip_type", F.col("trip_type").cast("double"))
    else:  # green
        ensure_double("trip_type")
        ensure_double("cbd_congestion_fee")
        if "airport_fee" not in df.columns:
            df = df.withColumn("airport_fee", F.lit(None).cast("double"))
        else:
            df = df.withColumn("airport_fee", F.col("airport_fee").cast("double"))

    return df

def ingest_one_month(service, y, m):
    """Descarga un parquet (temporal), lo ingesta idempotente y lo borra."""
    url = trip_url(service, y, m)
    tmp_path = f"{data_tmp}/{service}_{y}-{m:02d}.parquet"
    log(f"Iniciando {service.upper()} {y}-{m:02d}", "INFO")
    start = time.time()
    try:
        # 1) Descarga
        log(f"Descargando {url} ...", "INFO")
        r = requests.get(url, timeout=180)
        if r.status_code != 200:
            log(f"No encontrado ({r.status_code})", "WARN")
            return False
        with open(tmp_path, "wb") as f:
            f.write(r.content)
        log(f"Archivo descargado: {round(os.path.getsize(tmp_path)/1024/1024,2)} MB", "OK")

        # 2) Lectura con Spark
        log("Leyendo Parquet local con Spark...", "INFO")
        df = spark.read.parquet(tmp_path)
        log("Schema de origen:", "INFO")
        df.printSchema()

        # 3) Normalización de tipos + metadatos (usa tu common_casts existente)
        df, pickup_col, dropoff_col = common_casts(df, service)
        df = (
            df.withColumn("service", F.lit(service))
              .withColumn("year", F.lit(int(y)))
              .withColumn("month", F.lit(int(m)))
        )

        # 4) Alinear columnas opcionales (clave para 2025)
        df = align_raw_optional_columns(df, service)

        # Muestra para log
        sample_row = df.limit(1).toPandas().to_dict(orient="records")
        log(f"Fila de muestra: {sample_row}", "INFO")

        # 5) Idempotencia: borrar partición y escribir (una sola vez)
        tbl = target_table(service)
        delete_partition(service, y, m)

        # 🔒 Seguro anti-esquema: poda columnas que la tabla no tenga
        df = prune_before_write(df, tbl)

        log(f"Escribiendo en Postgres → {tbl}", "INFO")
        write_df(df, tbl, mode="append")
        log(f"{service.upper()} {y}-{m:02d} cargado correctamente en {tbl}", "OK")
        return True

    except Exception as e:
        log(f"Error en {service} {y}-{m:02d}: {e}", "ERROR")
        traceback.print_exc(limit=1)
        return False

    finally:
        if os.path.exists(tmp_path):
            os.remove(tmp_path)
            log(f"Archivo temporal eliminado: {tmp_path}", "INFO")
        elapsed = round(time.time() - start, 2)
        log(f"Tiempo total {service} {y}-{m:02d}: {elapsed}s", "INFO")
        print("-"*80)

# --- Ejecución (solo SELECTIVE_MONTHS = 2025 completo) ---
if SELECTIVE_MODE:
    log("===> Modo SELECTIVO", "INFO")
    for service, y, m in SELECTIVE_MONTHS:
        _ = ingest_one_month(service, y, m)
else:
    log("===> Modo COMPLETO", "INFO")
    for service in SERVICES:
        log(f"Servicio: {service}", "INFO")
        for y in YEARS:
            for m in range(1, 13):
                _ = ingest_one_month(service, y, m)

log("🏁 Ingesta terminada (según modo seleccionado)", "OK")
# Out:
# [21:18:01] ℹ️ ===> Modo SELECTIVO
# [21:18:01] ℹ️ Iniciando YELLOW 2025-01
# [21:18:01] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-01.parquet ...
# [21:18:41] ✅ Archivo descargado: 56.42 MB
# [21:18:41] ℹ️ Leyendo Parquet local con Spark...
# [21:18:42] ℹ️ Schema de origen:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- Airport_fee: double (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
#
# [21:18:43] ℹ️ Fila de muestra: [{'VendorID': 1, 'tpep_pickup_datetime': Timestamp('2025-01-01 00:18:38'), 'tpep_dropoff_datetime': Timestamp('2025-01-01 00:26:59'), 'passenger_count': 1, 'trip_distance': 1.6, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 229, 'DOLocationID': 237, 'payment_type': 1, 'fare_amount': 10.0, 'extra': 3.5, 'mta_tax': 0.5, 'tip_amount': 3.0, 'tolls_amount': 0.0, 'improvement_surcharge': 1.0, 'total_amount': 18.0, 'congestion_surcharge': 2.5, 'airport_fee': nan, 'cbd_congestion_fee': 0.0, 'ingested_at_utc': Timestamp('2025-11-04 21:18:42.436690'), 'run_id': 'dev-local-001', 'service': 'yellow', 'year': 2025, 'month': 1}]
# [21:18:43] ℹ️ Pre-DELETE → raw.yellow_taxi_trip (service=yellow, year=2025, month=1)
# [21:21:59] ✅ Pre-DELETE completado
# [21:21:59] ℹ️ Escribiendo en Postgres → raw.yellow_taxi_trip
# [21:22:26] ✅ YELLOW 2025-01 cargado correctamente en raw.yellow_taxi_trip
# [21:22:26] ℹ️ Archivo temporal eliminado: /home/jovyan/work/tmp_parquet/yellow_2025-01.parquet
# [21:22:26] ℹ️ Tiempo total yellow 2025-01: 264.36s
# --------------------------------------------------------------------------------
# [21:22:26] ℹ️ Iniciando YELLOW 2025-02
# [21:22:26] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-02.parquet ...
# [21:22:35] ✅ Archivo descargado: 57.55 MB
# [21:22:35] ℹ️ Leyendo Parquet local con Spark...
# [21:22:35] ℹ️ Schema de origen:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- Airport_fee: double (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
#
# [21:22:35] ℹ️ Fila de muestra: [{'VendorID': 2, 'tpep_pickup_datetime': Timestamp('2025-02-01 00:12:18'), 'tpep_dropoff_datetime': Timestamp('2025-02-01 00:32:33'), 'passenger_count': 3, 'trip_distance': 3.12, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 246, 'DOLocationID': 79, 'payment_type': 1, 'fare_amount': 19.8, 'extra': 1.0, 'mta_tax': 0.5, 'tip_amount': 5.11, 'tolls_amount': 0.0, 'improvement_surcharge': 1.0, 'total_amount': 30.66, 'congestion_surcharge': 2.5, 'airport_fee': nan, 'cbd_congestion_fee': 0.75, 'ingested_at_utc': Timestamp('2025-11-04 21:22:35.638261'), 'run_id': 'dev-local-001', 'service': 'yellow', 'year': 2025, 'month': 2}]
# [21:22:35] ℹ️ Pre-DELETE → raw.yellow_taxi_trip (service=yellow, year=2025, month=2)
# [21:26:07] ✅ Pre-DELETE completado
# [21:26:07] ℹ️ Escribiendo en Postgres → raw.yellow_taxi_trip
# [21:26:33] ✅ YELLOW 2025-02 cargado correctamente en raw.yellow_taxi_trip
# [21:26:33] ℹ️ Archivo temporal eliminado: /home/jovyan/work/tmp_parquet/yellow_2025-02.parquet
# [21:26:33] ℹ️ Tiempo total yellow 2025-02: 247.56s
# --------------------------------------------------------------------------------
# [21:26:33] ℹ️ Iniciando YELLOW 2025-03
# [21:26:33] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-03.parquet ...
# [21:27:21] ✅ Archivo descargado: 66.72 MB
# [21:27:21] ℹ️ Leyendo Parquet local con Spark...
# [21:27:21] ℹ️ Schema de origen:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- Airport_fee: double (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
#
# [21:27:22] ℹ️ Fila de muestra: [{'VendorID': 1, 'tpep_pickup_datetime': Timestamp('2025-03-01 00:17:16'), 'tpep_dropoff_datetime': Timestamp('2025-03-01 00:25:52'), 'passenger_count': 1, 'trip_distance': 0.9, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 140, 'DOLocationID': 236, 'payment_type': 1, 'fare_amount': 7.9, 'extra': 3.5, 'mta_tax': 0.5, 'tip_amount': 2.6, 'tolls_amount': 0.0, 'improvement_surcharge': 1.0, 'total_amount': 15.5, 'congestion_surcharge': 2.5, 'airport_fee': nan, 'cbd_congestion_fee': 0.0, 'ingested_at_utc': Timestamp('2025-11-04 21:27:22.023204'), 'run_id': 'dev-local-001', 'service': 'yellow', 'year': 2025, 'month': 3}]
# [21:27:22] ℹ️ Pre-DELETE → raw.yellow_taxi_trip (service=yellow, year=2025, month=3)
# [21:30:44] ✅ Pre-DELETE completado
# [21:30:44] ℹ️ Escribiendo en Postgres → raw.yellow_taxi_trip
# [21:31:11] ✅ YELLOW 2025-03 cargado correctamente en raw.yellow_taxi_trip
# [21:31:11] ℹ️ Archivo temporal eliminado: /home/jovyan/work/tmp_parquet/yellow_2025-03.parquet
# [21:31:11] ℹ️ Tiempo total yellow 2025-03: 277.73s
# --------------------------------------------------------------------------------
# [21:31:11] ℹ️ Iniciando YELLOW 2025-04
# [21:31:11] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-04.parquet ...
# [21:31:21] ✅ Archivo descargado: 64.23 MB
# [21:31:21] ℹ️ Leyendo Parquet local con Spark...
# [21:31:21] ℹ️ Schema de origen:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- Airport_fee: double (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
#
# [21:31:21] ℹ️ Fila de muestra: [{'VendorID': 1, 'tpep_pickup_datetime': Timestamp('2025-04-01 00:47:06'), 'tpep_dropoff_datetime': Timestamp('2025-04-01 01:13:25'), 'passenger_count': 1, 'trip_distance': 9.5, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 138, 'DOLocationID': 230, 'payment_type': 1, 'fare_amount': 38.7, 'extra': 11.0, 'mta_tax': 0.5, 'tip_amount': 11.65, 'tolls_amount': 6.94, 'improvement_surcharge': 1.0, 'total_amount': 69.79, 'congestion_surcharge': 2.5, 'airport_fee': nan, 'cbd_congestion_fee': 0.75, 'ingested_at_utc': Timestamp('2025-11-04 21:31:21.447873'), 'run_id': 'dev-local-001', 'service': 'yellow', 'year': 2025, 'month': 4}]
# [21:31:21] ℹ️ Pre-DELETE → raw.yellow_taxi_trip (service=yellow, year=2025, month=4)
# [21:34:48] ✅ Pre-DELETE completado
# [21:34:48] ℹ️ Escribiendo en Postgres → raw.yellow_taxi_trip
# [21:35:15] ✅ YELLOW 2025-04 cargado correctamente en raw.yellow_taxi_trip
# [21:35:15] ℹ️ Archivo temporal eliminado: /home/jovyan/work/tmp_parquet/yellow_2025-04.parquet
# [21:35:15] ℹ️ Tiempo total yellow 2025-04: 244.26s
# --------------------------------------------------------------------------------
# [21:35:15] ℹ️ Iniciando YELLOW 2025-05
# [21:35:15] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-05.parquet ...
# [21:36:00] ✅ Archivo descargado: 74.23 MB
# [21:36:00] ℹ️ Leyendo Parquet local con Spark...
# [21:36:00] ℹ️ Schema de origen:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- Airport_fee: double (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
#
# [21:36:01] ℹ️ Fila de muestra: [{'VendorID': 1, 'tpep_pickup_datetime': Timestamp('2025-05-01 00:07:06'), 'tpep_dropoff_datetime': Timestamp('2025-05-01 00:24:15'), 'passenger_count': 1, 'trip_distance': 3.7, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 140, 'DOLocationID': 202, 'payment_type': 1, 'fare_amount': 18.4, 'extra': 4.25, 'mta_tax': 0.5, 'tip_amount': 4.85, 'tolls_amount': 0.0, 'improvement_surcharge': 1.0, 'total_amount': 29.0, 'congestion_surcharge': 2.5, 'airport_fee': nan, 'cbd_congestion_fee': 0.75, 'ingested_at_utc': Timestamp('2025-11-04 21:36:00.838845'), 'run_id': 'dev-local-001', 'service': 'yellow', 'year': 2025, 'month': 5}]
# [21:36:01] ℹ️ Pre-DELETE → raw.yellow_taxi_trip (service=yellow, year=2025, month=5)
# [21:39:27] ✅ Pre-DELETE completado
# [21:39:27] ℹ️ Escribiendo en Postgres → raw.yellow_taxi_trip
# [21:39:58] ✅ YELLOW 2025-05 cargado correctamente en raw.yellow_taxi_trip
# [21:39:58] ℹ️ Archivo temporal eliminado: /home/jovyan/work/tmp_parquet/yellow_2025-05.parquet
# [21:39:58] ℹ️ Tiempo total yellow 2025-05: 283.1s
# --------------------------------------------------------------------------------
# [21:39:58] ℹ️ Iniciando YELLOW 2025-06
# [21:39:58] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-06.parquet ...
# [21:40:33] ✅ Archivo descargado: 70.14 MB
# [21:40:33] ℹ️ Leyendo Parquet local con Spark...
# [21:40:33] ℹ️ Schema de origen:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- Airport_fee: double (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
#
# [21:40:33] ℹ️ Fila de muestra: [{'VendorID': 1, 'tpep_pickup_datetime': Timestamp('2025-06-01 00:02:50'), 'tpep_dropoff_datetime': Timestamp('2025-06-01 00:39:51'), 'passenger_count': 1, 'trip_distance': 10.0, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 138, 'DOLocationID': 50, 'payment_type': 1, 'fare_amount': 47.8, 'extra': 11.0, 'mta_tax': 0.5, 'tip_amount': 20.15, 'tolls_amount': 6.94, 'improvement_surcharge': 1.0, 'total_amount': 87.39, 'congestion_surcharge': 2.5, 'airport_fee': nan, 'cbd_congestion_fee': 0.75, 'ingested_at_utc': Timestamp('2025-11-04 21:40:33.202775'), 'run_id': 'dev-local-001', 'service': 'yellow', 'year': 2025, 'month': 6}]
# [21:40:33] ℹ️ Pre-DELETE → raw.yellow_taxi_trip (service=yellow, year=2025, month=6)
# [21:44:01] ✅ Pre-DELETE completado
# [21:44:01] ℹ️ Escribiendo en Postgres → raw.yellow_taxi_trip
# [21:44:29] ✅ YELLOW 2025-06 cargado correctamente en raw.yellow_taxi_trip
# [21:44:29] ℹ️ Archivo temporal eliminado: /home/jovyan/work/tmp_parquet/yellow_2025-06.parquet
# [21:44:29] ℹ️ Tiempo total yellow 2025-06: 270.8s
# --------------------------------------------------------------------------------
# [21:44:29] ℹ️ Iniciando YELLOW 2025-07
# [21:44:29] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-07.parquet ...
# [21:44:46] ✅ Archivo descargado: 63.84 MB
# [21:44:46] ℹ️ Leyendo Parquet local con Spark...
# [21:44:47] ℹ️ Schema de origen:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- Airport_fee: double (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
#
# [21:44:47] ℹ️ Fila de muestra: [{'VendorID': 1, 'tpep_pickup_datetime': Timestamp('2025-07-01 00:29:37'), 'tpep_dropoff_datetime': Timestamp('2025-07-01 00:45:30'), 'passenger_count': 1, 'trip_distance': 7.3, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 138, 'DOLocationID': 74, 'payment_type': 1, 'fare_amount': 29.6, 'extra': 7.75, 'mta_tax': 0.5, 'tip_amount': 9.0, 'tolls_amount': 6.94, 'improvement_surcharge': 1.0, 'total_amount': 54.79, 'congestion_surcharge': 0.0, 'airport_fee': nan, 'cbd_congestion_fee': 0.0, 'ingested_at_utc': Timestamp('2025-11-04 21:44:47.087962'), 'run_id': 'dev-local-001', 'service': 'yellow', 'year': 2025, 'month': 7}]
# [21:44:47] ℹ️ Pre-DELETE → raw.yellow_taxi_trip (service=yellow, year=2025, month=7)
# [21:48:19] ✅ Pre-DELETE completado
# [21:48:19] ℹ️ Escribiendo en Postgres → raw.yellow_taxi_trip
# [21:48:45] ✅ YELLOW 2025-07 cargado correctamente en raw.yellow_taxi_trip
# [21:48:46] ℹ️ Archivo temporal eliminado: /home/jovyan/work/tmp_parquet/yellow_2025-07.parquet
# [21:48:46] ℹ️ Tiempo total yellow 2025-07: 256.35s
# --------------------------------------------------------------------------------
# [21:48:46] ℹ️ Iniciando YELLOW 2025-08
# [21:48:46] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-08.parquet ...
# [21:48:56] ✅ Archivo descargado: 59.41 MB
# [21:48:56] ℹ️ Leyendo Parquet local con Spark...
# [21:48:56] ℹ️ Schema de origen:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- Airport_fee: double (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
#
# [21:48:56] ℹ️ Fila de muestra: [{'VendorID': 2, 'tpep_pickup_datetime': Timestamp('2025-08-01 00:52:23'), 'tpep_dropoff_datetime': Timestamp('2025-08-01 01:12:20'), 'passenger_count': 1, 'trip_distance': 8.44, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 138, 'DOLocationID': 141, 'payment_type': 1, 'fare_amount': 33.8, 'extra': 6.0, 'mta_tax': 0.5, 'tip_amount': 5.0, 'tolls_amount': 6.94, 'improvement_surcharge': 1.0, 'total_amount': 57.49, 'congestion_surcharge': 2.5, 'airport_fee': nan, 'cbd_congestion_fee': 0.0, 'ingested_at_utc': Timestamp('2025-11-04 21:48:56.767277'), 'run_id': 'dev-local-001', 'service': 'yellow', 'year': 2025, 'month': 8}]
# [21:48:56] ℹ️ Pre-DELETE → raw.yellow_taxi_trip (service=yellow, year=2025, month=8)
# [21:52:30] ✅ Pre-DELETE completado
# [21:52:30] ℹ️ Escribiendo en Postgres → raw.yellow_taxi_trip
# [21:52:56] ✅ YELLOW 2025-08 cargado correctamente en raw.yellow_taxi_trip
# [21:52:56] ℹ️ Archivo temporal eliminado: /home/jovyan/work/tmp_parquet/yellow_2025-08.parquet
# [21:52:56] ℹ️ Tiempo total yellow 2025-08: 250.21s
# --------------------------------------------------------------------------------
# [21:52:56] ℹ️ Iniciando YELLOW 2025-09
# [21:52:56] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-09.parquet ...
# [21:53:24] ✅ Archivo descargado: 69.08 MB
# [21:53:24] ℹ️ Leyendo Parquet local con Spark...
# [21:53:24] ℹ️ Schema de origen:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- Airport_fee: double (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
#
# [21:53:24] ℹ️ Fila de muestra: [{'VendorID': 2, 'tpep_pickup_datetime': Timestamp('2025-09-01 00:19:20'), 'tpep_dropoff_datetime': Timestamp('2025-09-01 00:45:17'), 'passenger_count': 1, 'trip_distance': 9.92, 'RatecodeID': 1, 'store_and_fwd_flag': 'N', 'PULocationID': 138, 'DOLocationID': 114, 'payment_type': 1, 'fare_amount': 42.9, 'extra': 6.0, 'mta_tax': 0.5, 'tip_amount': 10.73, 'tolls_amount': 0.0, 'improvement_surcharge': 1.0, 'total_amount': 66.13, 'congestion_surcharge': 2.5, 'airport_fee': nan, 'cbd_congestion_fee': 0.75, 'ingested_at_utc': Timestamp('2025-11-04 21:53:24.637035'), 'run_id': 'dev-local-001', 'service': 'yellow', 'year': 2025, 'month': 9}]
# [21:53:24] ℹ️ Pre-DELETE → raw.yellow_taxi_trip (service=yellow, year=2025, month=9)
# [21:57:02] ✅ Pre-DELETE completado
# [21:57:03] ℹ️ Escribiendo en Postgres → raw.yellow_taxi_trip
# [21:57:31] ✅ YELLOW 2025-09 cargado correctamente en raw.yellow_taxi_trip
# [21:57:31] ℹ️ Archivo temporal eliminado: /home/jovyan/work/tmp_parquet/yellow_2025-09.parquet
# [21:57:31] ℹ️ Tiempo total yellow 2025-09: 275.19s
# --------------------------------------------------------------------------------
# [21:57:31] ℹ️ Iniciando YELLOW 2025-10
# [21:57:31] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-10.parquet ...
# [21:57:31] ⚠️ No encontrado (403)
# [21:57:31] ℹ️ Tiempo total yellow 2025-10: 0.41s
# --------------------------------------------------------------------------------
# [21:57:31] ℹ️ Iniciando YELLOW 2025-11
# [21:57:31] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-11.parquet ...
# [21:57:32] ⚠️ No encontrado (403)
# [21:57:32] ℹ️ Tiempo total yellow 2025-11: 0.44s
# --------------------------------------------------------------------------------
# [21:57:32] ℹ️ Iniciando YELLOW 2025-12
# [21:57:32] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-12.parquet ...
# [21:57:32] ⚠️ No encontrado (403)
# [21:57:32] ℹ️ Tiempo total yellow 2025-12: 0.35s
# --------------------------------------------------------------------------------
# [21:57:32] ℹ️ Iniciando GREEN 2025-01
# [21:57:32] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-01.parquet ...
# [21:57:33] ✅ Archivo descargado: 1.12 MB
# [21:57:33] ℹ️ Leyendo Parquet local con Spark...
# [21:57:33] ℹ️ Schema de origen:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- lpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- lpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- ehail_fee: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- trip_type: long (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
#
# [21:57:33] ℹ️ Fila de muestra: [{'VendorID': 2, 'lpep_pickup_datetime': Timestamp('2025-01-01 00:03:01'), 'lpep_dropoff_datetime': Timestamp('2025-01-01 00:17:12'), 'store_and_fwd_flag': 'N', 'RatecodeID': 1, 'PULocationID': 75, 'DOLocationID': 235, 'passenger_count': 1, 'trip_distance': 5.93, 'fare_amount': 24.7, 'extra': 1.0, 'mta_tax': 0.5, 'tip_amount': 6.8, 'tolls_amount': 0.0, 'ehail_fee': nan, 'improvement_surcharge': 1.0, 'total_amount': 34.0, 'payment_type': 1, 'trip_type': 1.0, 'congestion_surcharge': 0.0, 'cbd_congestion_fee': 0.0, 'ingested_at_utc': Timestamp('2025-11-04 21:57:33.444391'), 'run_id': 'dev-local-001', 'service': 'green', 'year': 2025, 'month': 1, 'airport_fee': nan}]
# [21:57:33] ℹ️ Pre-DELETE → raw.green_taxi_trip (service=green, year=2025, month=1)
# [21:57:51] ✅ Pre-DELETE completado
# [21:57:51] ⚠️ Podando columnas no presentes en raw.green_taxi_trip: ['airport_fee']
# [21:57:51] ℹ️ Escribiendo en Postgres → raw.green_taxi_trip
# [21:57:52] ✅ GREEN 2025-01 cargado correctamente en raw.green_taxi_trip
# [21:57:52] ℹ️ Archivo temporal eliminado: /home/jovyan/work/tmp_parquet/green_2025-01.parquet
# [21:57:52] ℹ️ Tiempo total green 2025-01: 19.98s
# --------------------------------------------------------------------------------
# [21:57:52] ℹ️ Iniciando GREEN 2025-02
# [21:57:52] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-02.parquet ...
# [21:57:53] ✅ Archivo descargado: 1.07 MB
# [21:57:53] ℹ️ Leyendo Parquet local con Spark...
# [21:57:53] ℹ️ Schema de origen:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- lpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- lpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- ehail_fee: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- trip_type: long (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
#
# [21:57:53] ℹ️ Fila de muestra: [{'VendorID': 2, 'lpep_pickup_datetime': Timestamp('2025-02-01 00:12:15'), 'lpep_dropoff_datetime': Timestamp('2025-02-01 00:15:48'), 'store_and_fwd_flag': 'N', 'RatecodeID': 1, 'PULocationID': 166, 'DOLocationID': 41, 'passenger_count': 1, 'trip_distance': 0.65, 'fare_amount': 6.5, 'extra': 1.0, 'mta_tax': 0.5, 'tip_amount': 1.8, 'tolls_amount': 0.0, 'ehail_fee': nan, 'improvement_surcharge': 1.0, 'total_amount': 10.8, 'payment_type': 1, 'trip_type': 1.0, 'congestion_surcharge': 0.0, 'cbd_congestion_fee': 0.0, 'ingested_at_utc': Timestamp('2025-11-04 21:57:53.414960'), 'run_id': 'dev-local-001', 'service': 'green', 'year': 2025, 'month': 2, 'airport_fee': nan}]
# [21:57:53] ℹ️ Pre-DELETE → raw.green_taxi_trip (service=green, year=2025, month=2)
# [21:58:12] ✅ Pre-DELETE completado
# [21:58:12] ⚠️ Podando columnas no presentes en raw.green_taxi_trip: ['airport_fee']
# [21:58:12] ℹ️ Escribiendo en Postgres → raw.green_taxi_trip
# [21:58:12] ✅ GREEN 2025-02 cargado correctamente en raw.green_taxi_trip
# [21:58:12] ℹ️ Archivo temporal eliminado: /home/jovyan/work/tmp_parquet/green_2025-02.parquet
# [21:58:12] ℹ️ Tiempo total green 2025-02: 20.29s
# --------------------------------------------------------------------------------
# [21:58:12] ℹ️ Iniciando GREEN 2025-03
# [21:58:12] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-03.parquet ...
# [21:58:14] ✅ Archivo descargado: 1.2 MB
# [21:58:14] ℹ️ Leyendo Parquet local con Spark...
# [21:58:14] ℹ️ Schema de origen:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- lpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- lpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- ehail_fee: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- trip_type: long (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
#
# [21:58:14] ℹ️ Fila de muestra: [{'VendorID': 2, 'lpep_pickup_datetime': Timestamp('2025-03-01 00:07:34'), 'lpep_dropoff_datetime': Timestamp('2025-03-01 00:24:52'), 'store_and_fwd_flag': 'N', 'RatecodeID': 1, 'PULocationID': 75, 'DOLocationID': 239, 'passenger_count': 1, 'trip_distance': 2.2, 'fare_amount': 18.4, 'extra': 1.0, 'mta_tax': 0.5, 'tip_amount': 5.91, 'tolls_amount': 0.0, 'ehail_fee': nan, 'improvement_surcharge': 1.0, 'total_amount': 29.56, 'payment_type': 1, 'trip_type': 1.0, 'congestion_surcharge': 2.75, 'cbd_congestion_fee': 0.0, 'ingested_at_utc': Timestamp('2025-11-04 21:58:14.194474'), 'run_id': 'dev-local-001', 'service': 'green', 'year': 2025, 'month': 3, 'airport_fee': nan}]
# [21:58:14] ℹ️ Pre-DELETE → raw.green_taxi_trip (service=green, year=2025, month=3)
# [21:58:32] ✅ Pre-DELETE completado
# [21:58:32] ⚠️ Podando columnas no presentes en raw.green_taxi_trip: ['airport_fee']
# [21:58:32] ℹ️ Escribiendo en Postgres → raw.green_taxi_trip
# [21:58:33] ✅ GREEN 2025-03 cargado correctamente en raw.green_taxi_trip
# [21:58:33] ℹ️ Archivo temporal eliminado: /home/jovyan/work/tmp_parquet/green_2025-03.parquet
# [21:58:33] ℹ️ Tiempo total green 2025-03: 20.78s
# --------------------------------------------------------------------------------
# [21:58:33] ℹ️ Iniciando GREEN 2025-04
# [21:58:33] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-04.parquet ...
# [21:58:34] ✅ Archivo descargado: 1.21 MB
# [21:58:34] ℹ️ Leyendo Parquet local con Spark...
# [21:58:34] ℹ️ Schema de origen:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- lpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- lpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- ehail_fee: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- trip_type: long (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
#
# [21:58:34] ℹ️ Fila de muestra: [{'VendorID': 2, 'lpep_pickup_datetime': Timestamp('2025-04-01 00:36:05'), 'lpep_dropoff_datetime': Timestamp('2025-04-01 00:42:00'), 'store_and_fwd_flag': 'N', 'RatecodeID': 1, 'PULocationID': 75, 'DOLocationID': 41, 'passenger_count': 1, 'trip_distance': 1.37, 'fare_amount': 8.6, 'extra': 1.0, 'mta_tax': 0.5, 'tip_amount': 1.0, 'tolls_amount': 0.0, 'ehail_fee': nan, 'improvement_surcharge': 1.0, 'total_amount': 12.1, 'payment_type': 1, 'trip_type': 1.0, 'congestion_surcharge': 0.0, 'cbd_congestion_fee': 0.0, 'ingested_at_utc': Timestamp('2025-11-04 21:58:34.737400'), 'run_id': 'dev-local-001', 'service': 'green', 'year': 2025, 'month': 4, 'airport_fee': nan}]
# [21:58:34] ℹ️ Pre-DELETE → raw.green_taxi_trip (service=green, year=2025, month=4)
# [21:58:53] ✅ Pre-DELETE completado
# [21:58:53] ⚠️ Podando columnas no presentes en raw.green_taxi_trip: ['airport_fee']
# [21:58:53] ℹ️ Escribiendo en Postgres → raw.green_taxi_trip
# [21:58:54] ✅ GREEN 2025-04 cargado correctamente en raw.green_taxi_trip
# [21:58:54] ℹ️ Archivo temporal eliminado: /home/jovyan/work/tmp_parquet/green_2025-04.parquet
# [21:58:54] ℹ️ Tiempo total green 2025-04: 20.57s
# --------------------------------------------------------------------------------
# [21:58:54] ℹ️ Iniciando GREEN 2025-05
# [21:58:54] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-05.parquet ...
# [21:58:55] ✅ Archivo descargado: 1.28 MB
# [21:58:55] ℹ️ Leyendo Parquet local con Spark...
# [21:58:55] ℹ️ Schema de origen:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- lpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- lpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- ehail_fee: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- trip_type: long (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
#
# [21:58:55] ℹ️ Fila de muestra: [{'VendorID': 2, 'lpep_pickup_datetime': Timestamp('2025-05-01 00:17:04'), 'lpep_dropoff_datetime': Timestamp('2025-05-01 00:56:06'), 'store_and_fwd_flag': 'N', 'RatecodeID': 1, 'PULocationID': 25, 'DOLocationID': 216, 'passenger_count': 1, 'trip_distance': 9.34, 'fare_amount': 44.3, 'extra': 1.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'ehail_fee': nan, 'improvement_surcharge': 1.0, 'total_amount': 46.8, 'payment_type': 1, 'trip_type': 1.0, 'congestion_surcharge': 0.0, 'cbd_congestion_fee': 0.0, 'ingested_at_utc': Timestamp('2025-11-04 21:58:55.329478'), 'run_id': 'dev-local-001', 'service': 'green', 'year': 2025, 'month': 5, 'airport_fee': nan}]
# [21:58:55] ℹ️ Pre-DELETE → raw.green_taxi_trip (service=green, year=2025, month=5)
# [21:59:13] ✅ Pre-DELETE completado
# [21:59:14] ⚠️ Podando columnas no presentes en raw.green_taxi_trip: ['airport_fee']
# [21:59:14] ℹ️ Escribiendo en Postgres → raw.green_taxi_trip
# [21:59:14] ✅ GREEN 2025-05 cargado correctamente en raw.green_taxi_trip
# [21:59:14] ℹ️ Archivo temporal eliminado: /home/jovyan/work/tmp_parquet/green_2025-05.parquet
# [21:59:14] ℹ️ Tiempo total green 2025-05: 20.64s
# --------------------------------------------------------------------------------
# [21:59:14] ℹ️ Iniciando GREEN 2025-06
# [21:59:14] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-06.parquet ...
# [21:59:15] ✅ Archivo descargado: 1.16 MB
# [21:59:15] ℹ️ Leyendo Parquet local con Spark...
# [21:59:15] ℹ️ Schema de origen:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- lpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- lpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- ehail_fee: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- trip_type: long (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
#
# [21:59:16] ℹ️ Fila de muestra: [{'VendorID': 2, 'lpep_pickup_datetime': Timestamp('2025-06-01 00:33:43'), 'lpep_dropoff_datetime': Timestamp('2025-06-01 01:04:33'), 'store_and_fwd_flag': 'N', 'RatecodeID': 2, 'PULocationID': 74, 'DOLocationID': 132, 'passenger_count': 1, 'trip_distance': 19.6, 'fare_amount': 70.0, 'extra': 0.0, 'mta_tax': 0.5, 'tip_amount': 19.61, 'tolls_amount': 6.94, 'ehail_fee': nan, 'improvement_surcharge': 1.0, 'total_amount': 98.05, 'payment_type': 1, 'trip_type': 1.0, 'congestion_surcharge': 0.0, 'cbd_congestion_fee': 0.0, 'ingested_at_utc': Timestamp('2025-11-04 21:59:15.983578'), 'run_id': 'dev-local-001', 'service': 'green', 'year': 2025, 'month': 6, 'airport_fee': nan}]
# [21:59:16] ℹ️ Pre-DELETE → raw.green_taxi_trip (service=green, year=2025, month=6)
# [21:59:34] ✅ Pre-DELETE completado
# [21:59:34] ⚠️ Podando columnas no presentes en raw.green_taxi_trip: ['airport_fee']
# [21:59:34] ℹ️ Escribiendo en Postgres → raw.green_taxi_trip
# [21:59:35] ✅ GREEN 2025-06 cargado correctamente en raw.green_taxi_trip
# [21:59:35] ℹ️ Archivo temporal eliminado: /home/jovyan/work/tmp_parquet/green_2025-06.parquet
# [21:59:35] ℹ️ Tiempo total green 2025-06: 20.79s
# --------------------------------------------------------------------------------
# [21:59:35] ℹ️ Iniciando GREEN 2025-07
# [21:59:35] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-07.parquet ...
# [21:59:36] ✅ Archivo descargado: 1.13 MB
# [21:59:36] ℹ️ Leyendo Parquet local con Spark...
# [21:59:36] ℹ️ Schema de origen:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- lpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- lpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- ehail_fee: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- trip_type: long (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
#
# [21:59:37] ℹ️ Fila de muestra: [{'VendorID': 2, 'lpep_pickup_datetime': Timestamp('2025-07-01 00:48:04'), 'lpep_dropoff_datetime': Timestamp('2025-07-01 01:03:36'), 'store_and_fwd_flag': 'N', 'RatecodeID': 1, 'PULocationID': 223, 'DOLocationID': 82, 'passenger_count': 1, 'trip_distance': 7.63, 'fare_amount': 31.7, 'extra': 1.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'ehail_fee': nan, 'improvement_surcharge': 1.0, 'total_amount': 34.2, 'payment_type': 2, 'trip_type': 1.0, 'congestion_surcharge': 0.0, 'cbd_congestion_fee': 0.0, 'ingested_at_utc': Timestamp('2025-11-04 21:59:36.908373'), 'run_id': 'dev-local-001', 'service': 'green', 'year': 2025, 'month': 7, 'airport_fee': nan}]
# [21:59:37] ℹ️ Pre-DELETE → raw.green_taxi_trip (service=green, year=2025, month=7)
# [21:59:54] ✅ Pre-DELETE completado
# [21:59:54] ⚠️ Podando columnas no presentes en raw.green_taxi_trip: ['airport_fee']
# [21:59:54] ℹ️ Escribiendo en Postgres → raw.green_taxi_trip
# [21:59:55] ✅ GREEN 2025-07 cargado correctamente en raw.green_taxi_trip
# [21:59:55] ℹ️ Archivo temporal eliminado: /home/jovyan/work/tmp_parquet/green_2025-07.parquet
# [21:59:55] ℹ️ Tiempo total green 2025-07: 19.89s
# --------------------------------------------------------------------------------
# [21:59:55] ℹ️ Iniciando GREEN 2025-08
# [21:59:55] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-08.parquet ...
# [21:59:56] ✅ Archivo descargado: 1.1 MB
# [21:59:56] ℹ️ Leyendo Parquet local con Spark...
# [21:59:56] ℹ️ Schema de origen:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- lpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- lpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- ehail_fee: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- trip_type: long (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
#
# [21:59:56] ℹ️ Fila de muestra: [{'VendorID': 2, 'lpep_pickup_datetime': Timestamp('2025-08-01 00:33:57'), 'lpep_dropoff_datetime': Timestamp('2025-08-01 00:58:10'), 'store_and_fwd_flag': 'N', 'RatecodeID': 1, 'PULocationID': 70, 'DOLocationID': 82, 'passenger_count': 1, 'trip_distance': 2.44, 'fare_amount': 21.9, 'extra': 1.0, 'mta_tax': 0.5, 'tip_amount': 0.0, 'tolls_amount': 0.0, 'ehail_fee': nan, 'improvement_surcharge': 1.0, 'total_amount': 24.4, 'payment_type': 2, 'trip_type': 1.0, 'congestion_surcharge': 0.0, 'cbd_congestion_fee': 0.0, 'ingested_at_utc': Timestamp('2025-11-04 21:59:56.317900'), 'run_id': 'dev-local-001', 'service': 'green', 'year': 2025, 'month': 8, 'airport_fee': nan}]
# [21:59:56] ℹ️ Pre-DELETE → raw.green_taxi_trip (service=green, year=2025, month=8)
# [22:00:14] ✅ Pre-DELETE completado
# [22:00:14] ⚠️ Podando columnas no presentes en raw.green_taxi_trip: ['airport_fee']
# [22:00:14] ℹ️ Escribiendo en Postgres → raw.green_taxi_trip
# [22:00:14] ✅ GREEN 2025-08 cargado correctamente en raw.green_taxi_trip
# [22:00:14] ℹ️ Archivo temporal eliminado: /home/jovyan/work/tmp_parquet/green_2025-08.parquet
# [22:00:14] ℹ️ Tiempo total green 2025-08: 19.11s
# --------------------------------------------------------------------------------
# [22:00:14] ℹ️ Iniciando GREEN 2025-09
# [22:00:14] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-09.parquet ...
# [22:00:16] ✅ Archivo descargado: 1.15 MB
# [22:00:16] ℹ️ Leyendo Parquet local con Spark...
# [22:00:16] ℹ️ Schema de origen:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- lpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- lpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- ehail_fee: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- trip_type: long (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
#
# [22:00:16] ℹ️ Fila de muestra: [{'VendorID': 2, 'lpep_pickup_datetime': Timestamp('2025-09-01 00:06:49'), 'lpep_dropoff_datetime': Timestamp('2025-09-01 00:17:31'), 'store_and_fwd_flag': 'N', 'RatecodeID': 1, 'PULocationID': 74, 'DOLocationID': 263, 'passenger_count': 1, 'trip_distance': 1.86, 'fare_amount': 12.8, 'extra': 1.0, 'mta_tax': 0.5, 'tip_amount': 3.06, 'tolls_amount': 0.0, 'ehail_fee': nan, 'improvement_surcharge': 1.0, 'total_amount': 18.36, 'payment_type': 1, 'trip_type': 1.0, 'congestion_surcharge': 0.0, 'cbd_congestion_fee': 0.0, 'ingested_at_utc': Timestamp('2025-11-04 22:00:16.219709'), 'run_id': 'dev-local-001', 'service': 'green', 'year': 2025, 'month': 9, 'airport_fee': nan}]
# [22:00:16] ℹ️ Pre-DELETE → raw.green_taxi_trip (service=green, year=2025, month=9)
# [22:00:34] ✅ Pre-DELETE completado
# [22:00:34] ⚠️ Podando columnas no presentes en raw.green_taxi_trip: ['airport_fee']
# [22:00:34] ℹ️ Escribiendo en Postgres → raw.green_taxi_trip
# [22:00:34] ✅ GREEN 2025-09 cargado correctamente en raw.green_taxi_trip
# [22:00:34] ℹ️ Archivo temporal eliminado: /home/jovyan/work/tmp_parquet/green_2025-09.parquet
# [22:00:34] ℹ️ Tiempo total green 2025-09: 20.25s
# --------------------------------------------------------------------------------
# [22:00:34] ℹ️ Iniciando GREEN 2025-10
# [22:00:34] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-10.parquet ...
# [22:00:35] ⚠️ No encontrado (403)
# [22:00:35] ℹ️ Tiempo total green 2025-10: 0.34s
# --------------------------------------------------------------------------------
# [22:00:35] ℹ️ Iniciando GREEN 2025-11
# [22:00:35] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-11.parquet ...
# [22:00:35] ⚠️ No encontrado (403)
# [22:00:35] ℹ️ Tiempo total green 2025-11: 0.32s
# --------------------------------------------------------------------------------
# [22:00:35] ℹ️ Iniciando GREEN 2025-12
# [22:00:35] ℹ️ Descargando https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-12.parquet ...
# [22:00:36] ⚠️ No encontrado (403)
# [22:00:36] ℹ️ Tiempo total green 2025-12: 0.39s
# --------------------------------------------------------------------------------
# [22:00:36] ✅ 🏁 Ingesta terminada (según modo seleccionado)

# %%
# === Helpers mínimos (ajusta si tus env vars son otras) ===
import os
from pyspark.sql import SparkSession

PG_HOST = os.getenv("PG_HOST", "postgres")
PG_PORT = int(os.getenv("PG_PORT", "5432"))
PG_DB   = os.getenv("PG_DB", "nyc_taxi")
PG_USER = os.getenv("PG_USER", "postgres")
PG_PASS = os.getenv("PG_PASSWORD", "postgres")
SCHEMA_RAW = os.getenv("PG_SCHEMA_RAW", "raw")
SCHEMA_AN  = os.getenv("PG_SCHEMA_ANALYTICS", "analytics")

JDBC_URL = f"jdbc:postgresql://{PG_HOST}:{PG_PORT}/{PG_DB}"
JDBC_OPTS = {
    "url": JDBC_URL,
    "driver": "org.postgresql.Driver",
    "user": PG_USER,
    "password": PG_PASS,
}

def target_table(service: str) -> str:
    return f"{SCHEMA_RAW}.{service}_taxi_trip"

def jdbc_df(sql: str):
    return (
        spark.read.format("jdbc")
        .options(**JDBC_OPTS)
        .option("dbtable", f"({sql}) t")
        .load()
    )

# === 1) Conteo global y rango de años por servicio en RAW ===
sql_totales = f"""
SELECT 'yellow' AS service, COUNT(*) AS n, MIN(year) AS y0, MAX(year) AS y1
FROM {SCHEMA_RAW}.yellow_taxi_trip
UNION ALL
SELECT 'green'  AS service, COUNT(*) AS n, MIN(year) AS y0, MAX(year) AS y1
FROM {SCHEMA_RAW}.green_taxi_trip
"""
df_tot = jdbc_df(sql_totales)
print("== RAW: totales y rango de años ==")
df_tot.show(truncate=False)

# === 5) Muestra rápida por servicio/año-mes (para sanity check) ===
sql_sample = f"""
SELECT 'yellow' AS service, year, month, COUNT(*) AS n
FROM {SCHEMA_RAW}.yellow_taxi_trip
GROUP BY year, month
ORDER BY year, month
"""
jdbc_df(sql_sample).show(24, truncate=False)
# Out:
# == RAW: totales y rango de años ==
# +-------+---------+----+----+
# |service|n        |y0  |y1  |
# +-------+---------+----+----+
# |yellow |788638091|2015|2025|
# |green  |62032465 |2015|2025|
# +-------+---------+----+----+
#
# +-------+----+-----+--------+
# |service|year|month|n       |
# +-------+----+-----+--------+
# |yellow |2015|1    |12741035|
# |yellow |2015|2    |12442394|
# |yellow |2015|3    |13342951|
# |yellow |2015|4    |13063758|
# |yellow |2015|5    |13157677|
# |yellow |2015|6    |12324936|
# |yellow |2015|7    |11559666|
# |yellow |2015|8    |11123123|
# |yellow |2015|9    |11218122|
# |yellow |2015|10   |12307333|
# |yellow |2015|11   |11305240|
# |yellow |2015|12   |11452996|
# |yellow |2016|1    |10905067|
# |yellow |2016|2    |11375412|
# |yellow |2016|3    |12203824|
# |yellow |2016|4    |11927996|
# |yellow |2016|5    |11832049|
# |yellow |2016|6    |11131645|
# |yellow |2016|7    |10294080|
# |yellow |2016|8    |9942263 |
# |yellow |2016|9    |10116018|
# |yellow |2016|10   |10854626|
# |yellow |2016|11   |10102128|
# |yellow |2016|12   |10446697|
# +-------+----+-----+--------+
# only showing top 24 rows

# %%
# --- Resumen por servicio/año/mes
q_counts = """
(SELECT service, year, month, COUNT(*) AS n
   FROM analytics.obt_trips
  GROUP BY 1,2,3
  ORDER BY 1,2,3) t
"""
df_counts = (spark.read.format("jdbc")
             .options(**JDBC_OPTS)
             .option("dbtable", q_counts)
             .load())
print("### analytics.obt_trips — conteos por partición")
df_counts.show(100, truncate=False)

# --- Totales globales
q_tot = "(SELECT COUNT(*) AS rows, SUM(total_amount) AS total_amount FROM analytics.obt_trips) t"
df_tot = (spark.read.format("jdbc")
          .options(**JDBC_OPTS)
          .option("dbtable", q_tot)
          .load())
print("### Totales globales")
df_tot.show(truncate=False)
# Out:
# ### analytics.obt_trips — conteos por partición
# +-------+----+-----+-------+
# |service|year|month|n      |
# +-------+----+-----+-------+
# |green  |2015|1    |3012518|
# |green  |2015|2    |1572522|
# |green  |2015|3    |1720105|
# |green  |2015|4    |1661954|
# |green  |2015|5    |1784212|
# |green  |2015|6    |1636369|
# |green  |2015|7    |1539138|
# |green  |2015|8    |1529825|
# |green  |2015|9    |1492494|
# |green  |2015|10   |1627586|
# |green  |2015|11   |1526914|
# |green  |2015|12   |1605133|
# |green  |2016|1    |1442303|
# |green  |2016|2    |1507808|
# |green  |2016|7    |1329794|
# |green  |2016|8    |1245039|
# |green  |2016|9    |1160093|
# |green  |2016|10   |1250098|
# |green  |2016|11   |1145735|
# |green  |2016|12   |1221346|
# |green  |2017|1    |1067199|
# |green  |2017|2    |1019942|
# |green  |2017|3    |1155219|
# |green  |2017|4    |1078456|
# |green  |2017|5    |1057165|
# |green  |2017|6    |974346 |
# |green  |2017|7    |912693 |
# |green  |2017|8    |865426 |
# |green  |2017|9    |880491 |
# |green  |2017|10   |923637 |
# |green  |2017|11   |871996 |
# |green  |2017|12   |903709 |
# |green  |2018|1    |790803 |
# |green  |2018|2    |767342 |
# |green  |2018|3    |834055 |
# |green  |2018|4    |797350 |
# |green  |2018|5    |794557 |
# |green  |2018|6    |736625 |
# |green  |2018|7    |682532 |
# |green  |2018|8    |674007 |
# |green  |2018|9    |680330 |
# |green  |2018|10   |729961 |
# |green  |2018|11   |671418 |
# |green  |2018|12   |717621 |
# |green  |2019|1    |669534 |
# |green  |2019|2    |613499 |
# |green  |2019|3    |640699 |
# |green  |2019|4    |565858 |
# |green  |2019|5    |543893 |
# |green  |2019|6    |504896 |
# |green  |2019|7    |469495 |
# |green  |2019|8    |448354 |
# |green  |2019|9    |447849 |
# |green  |2019|10   |474995 |
# |green  |2019|11   |432209 |
# |green  |2019|12   |451070 |
# |green  |2020|1    |445779 |
# |green  |2020|2    |397463 |
# |green  |2020|3    |222773 |
# |green  |2020|4    |35510  |
# |green  |2020|5    |57242  |
# |green  |2020|6    |62968  |
# |green  |2020|7    |72113  |
# |green  |2020|8    |80891  |
# |green  |2020|9    |87801  |
# |green  |2020|10   |94930  |
# |green  |2020|11   |88430  |
# |green  |2020|12   |82948  |
# |green  |2021|1    |76384  |
# |green  |2021|2    |64461  |
# |green  |2021|3    |83678  |
# |green  |2021|4    |86753  |
# |green  |2021|5    |88060  |
# |green  |2021|6    |86601  |
# |green  |2021|7    |83545  |
# |green  |2021|8    |83354  |
# |green  |2021|9    |95538  |
# |green  |2021|10   |110646 |
# |green  |2021|11   |107949 |
# |green  |2021|12   |99659  |
# |green  |2022|1    |62284  |
# |green  |2022|2    |69198  |
# |green  |2022|3    |78321  |
# |green  |2022|4    |75953  |
# |green  |2022|5    |76717  |
# |green  |2022|6    |73533  |
# |green  |2022|7    |64022  |
# |green  |2022|8    |65768  |
# |green  |2022|9    |68850  |
# |green  |2022|10   |69172  |
# |green  |2022|11   |62141  |
# |green  |2022|12   |72217  |
# |green  |2023|1    |68030  |
# |green  |2023|2    |64620  |
# |green  |2023|3    |71844  |
# |green  |2023|4    |65215  |
# |green  |2023|5    |68999  |
# |green  |2023|6    |65375  |
# |green  |2023|7    |61176  |
# |green  |2023|8    |60457  |
# +-------+----+-----+-------+
# only showing top 100 rows
#
# ### Totales globales
# +---------+---------------------+
# |rows     |total_amount         |
# +---------+---------------------+
# |862092397|1.6033198214017061E10|
# +---------+---------------------+

# %%
# --- Top zonas de pickup por viajes y por facturación (ajusta año/mes si quieres)
YEAR, MONTH = 2015, 1

q_top_trips = f"""
(SELECT pu_borough, pu_zone, COUNT(*) AS trips
   FROM analytics.obt_trips
  WHERE year={YEAR} AND month={MONTH}
  GROUP BY 1,2
  ORDER BY trips DESC
  LIMIT 10) t
"""
q_top_amount = f"""
(SELECT pu_borough, pu_zone, SUM(total_amount) AS total_usd
   FROM analytics.obt_trips
  WHERE year={YEAR} AND month={MONTH}
  GROUP BY 1,2
  ORDER BY total_usd DESC
  LIMIT 10) t
"""

df_top_trips = (spark.read.format("jdbc").options(**JDBC_OPTS).option("dbtable", q_top_trips).load())
df_top_amount = (spark.read.format("jdbc").options(**JDBC_OPTS).option("dbtable", q_top_amount).load())

print(f"### Top 10 zonas por viajes — {YEAR}-{MONTH:02d}")
df_top_trips.show(truncate=False)
print(f"### Top 10 zonas por facturación — {YEAR}-{MONTH:02d}")
df_top_amount.show(truncate=False)

# --- Chequeos de calidad
q_nulls = f"""
(SELECT
    SUM(CASE WHEN pickup_ts IS NULL THEN 1 ELSE 0 END) AS null_pickup,
    SUM(CASE WHEN dropoff_ts IS NULL THEN 1 ELSE 0 END) AS null_dropoff,
    SUM(CASE WHEN pu_location_id IS NULL THEN 1 ELSE 0 END) AS null_pu_loc,
    SUM(CASE WHEN do_location_id IS NULL THEN 1 ELSE 0 END) AS null_do_loc,
    SUM(CASE WHEN total_amount IS NULL THEN 1 ELSE 0 END) AS null_total
  FROM analytics.obt_trips
 WHERE year={YEAR} AND month={MONTH}) t
"""
df_nulls = (spark.read.format("jdbc").options(**JDBC_OPTS).option("dbtable", q_nulls).load())
print("### Nulos clave (pickup/dropoff/zona/total)")
df_nulls.show(truncate=False)

# --- Muestra de filas (para evidencias)
q_sample = f"""
(SELECT service, year, month, vendor_id, pickup_ts, dropoff_ts,
        pu_borough, pu_zone, do_borough, do_zone,
        total_amount, airport_fee, cbd_congestion_fee, trip_type
   FROM analytics.obt_trips
  WHERE year={YEAR} AND month={MONTH}
  LIMIT 5) t
"""
df_sample = (spark.read.format("jdbc").options(**JDBC_OPTS).option("dbtable", q_sample).load())
print("### Muestra de filas")
df_sample.show(truncate=False)
# Out:
# ### Top 10 zonas por viajes — 2015-01
# +----------+----------------------------+------+
# |pu_borough|pu_zone                     |trips |
# +----------+----------------------------+------+
# |Manhattan |Upper East Side South       |467013|
# |Manhattan |Midtown Center              |446282|
# |Manhattan |Upper East Side North       |445117|
# |Manhattan |East Village                |437630|
# |Manhattan |Times Sq/Theatre District   |429122|
# |Manhattan |Union Sq                    |423061|
# |Manhattan |Murray Hill                 |411186|
# |Manhattan |Midtown East                |410487|
# |Manhattan |Clinton East                |400812|
# |Manhattan |Penn Station/Madison Sq West|392878|
# +----------+----------------------------+------+
#
# ### Top 10 zonas por facturación — 2015-01
# +----------+-------------------------+-------------------+
# |pu_borough|pu_zone                  |total_usd          |
# +----------+-------------------------+-------------------+
# |Queens    |JFK Airport              |1.283756118998953E7|
# |Queens    |LaGuardia Airport        |9829530.75999234   |
# |Manhattan |West Village             |7754007.5600020895 |
# |Manhattan |Times Sq/Theatre District|6124732.570006989  |
# |Manhattan |East Village             |5994440.810006003  |
# |Manhattan |Midtown Center           |5959430.760007646  |
# |Manhattan |Midtown East             |5576498.040006975  |
# |Manhattan |Union Sq                 |5410886.740006905  |
# |Manhattan |Murray Hill              |5362952.920006781  |
# |Manhattan |Clinton East             |5357457.020007437  |
# +----------+-------------------------+-------------------+
#
# ### Nulos clave (pickup/dropoff/zona/total)
# +-----------+------------+-----------+-----------+----------+
# |null_pickup|null_dropoff|null_pu_loc|null_do_loc|null_total|
# +-----------+------------+-----------+-----------+----------+
# |0          |0           |0          |0          |0         |
# +-----------+------------+-----------+-----------+----------+
#
# ### Muestra de filas
# +-------+----+-----+---------+-------------------+-------------------+----------+-----------------------+----------+---------------------+------------+-----------+------------------+---------+
# |service|year|month|vendor_id|pickup_ts          |dropoff_ts         |pu_borough|pu_zone                |do_borough|do_zone              |total_amount|airport_fee|cbd_congestion_fee|trip_type|
# +-------+----+-----+---------+-------------------+-------------------+----------+-----------------------+----------+---------------------+------------+-----------+------------------+---------+
# |yellow |2015|1    |1        |2015-01-23 15:26:55|2015-01-23 15:36:17|Manhattan |Upper West Side South  |Manhattan |Upper East Side North|10.5        |NULL       |NULL              |NULL     |
# |yellow |2015|1    |1        |2015-01-23 15:43:35|2015-01-23 15:49:15|Manhattan |Yorkville West         |Manhattan |East Harlem South    |6.3         |NULL       |NULL              |NULL     |
# |yellow |2015|1    |2        |2015-01-23 15:08:05|2015-01-23 15:17:15|Manhattan |Greenwich Village South|Manhattan |Union Sq             |11.0        |NULL       |NULL              |NULL     |
# |yellow |2015|1    |2        |2015-01-23 15:20:29|2015-01-23 15:28:43|Manhattan |Midtown South          |Manhattan |Midtown South        |7.3         |NULL       |NULL              |NULL     |
# |yellow |2015|1    |2        |2015-01-23 15:29:43|2015-01-23 15:35:56|Manhattan |Midtown South          |Manhattan |Midtown North        |6.8         |NULL       |NULL              |NULL     |
# +-------+----+-----+---------+-------------------+-------------------+----------+-----------------------+----------+---------------------+------------+-----------+------------------+---------+

# %%
# === Parámetros ===
YEAR   = 2015     # cambia si quieres
MONTH  = 1        # cambia si quieres
SERVICES = ["yellow","green"]  # o ["yellow"] / ["green"]

from pyspark.sql import functions as F

svc_list = ",".join([f"'{s}'" for s in SERVICES])
base_sql = f"""
(SELECT *
   FROM analytics.obt_trips
  WHERE year={YEAR} AND month={MONTH}
    AND service IN ({svc_list})
)
"""

df = (spark.read.format("jdbc")
      .options(**JDBC_OPTS)
      .option("dbtable", base_sql)
      .load())

print("### Muestra")
df.select("service","year","month","vendor_id","pickup_ts","dropoff_ts",
          "trip_distance","total_amount","passenger_count","ratecode_id","payment_type").show(5, truncate=False)

# --- Derivadas útiles ---
df2 = (
    df
    .withColumn("duration_min", (F.col("dropoff_ts").cast("long") - F.col("pickup_ts").cast("long"))/60.0)
    .withColumn("duration_hr",  F.col("duration_min")/60.0)
    .withColumn("mph", F.when(F.col("duration_hr")>0, F.col("trip_distance")/F.col("duration_hr")))
)

# --- Reglas de calidad (puedes ajustar umbrales si tu profesor lo pide distinto) ---
bad = {
  "null_timestamps"     : (F.col("pickup_ts").isNull() | F.col("dropoff_ts").isNull()),
  "inverted_times"      : (F.col("pickup_ts") > F.col("dropoff_ts")),
  "neg_distance"        : (F.col("trip_distance") < 0),
  "huge_distance"       : (F.col("trip_distance") > 200),   # 200 millas intra-NYC es sospechoso
  "neg_amount"          : (F.col("total_amount") < 0),
  "huge_amount"         : (F.col("total_amount") > 1000),   # > $1000 muy raro
  "pc_out_of_range"     : (F.col("passenger_count").isNotNull() & ~F.col("passenger_count").between(0,8)),
  "ratecode_out"        : (F.col("ratecode_id").isNotNull() & ~F.col("ratecode_id").isin(1,2,3,4,5,6,99)),
  "payment_out"         : (F.col("payment_type").isNotNull() & ~F.col("payment_type").isin(0,1,2,3,4,5,6)),
  "zero_or_neg_duration": (F.col("duration_min") <= 0),
  "ultra_long_duration" : (F.col("duration_min") > 600),     # >10 horas
  "mph_too_fast"        : (F.col("mph") > 100),              # >100 mph sostenido improbable
  "mph_too_slow"        : (F.col("mph") < 1) & (F.col("trip_distance") > 0.5)  # muy lento para >0.5mi
}

# --- Resumen por servicio ---
aggs = [F.sum(F.when(cond, F.lit(1)).otherwise(F.lit(0))).alias(name) for name, cond in bad.items()]
summary = (df2.groupBy("service")
           .agg(F.count(F.lit(1)).alias("rows"), *aggs)
           .orderBy("service"))
print("### Resumen de anomalías por servicio")
summary.show(truncate=False)

# --- Totales globales (del filtro YEAR/MONTH/SERVICES) ---
summary_tot = df2.agg(F.count(F.lit(1)).alias("rows_total"), *aggs)
print("### Totales de anomalías (periodo seleccionado)")
summary_tot.show(truncate=False)

# --- Percentiles rápidos para contexto (distancia, total, duración, mph) ---
def pct_query(col):
    return (df2
            .select(col)
            .summary("count","min","25%","50%","75%","95%","99%","max"))
print("### Percentiles trip_distance"); pct_query("trip_distance").show(truncate=False)
print("### Percentiles total_amount");  pct_query("total_amount").show(truncate=False)
print("### Percentiles duration_min"); pct_query("duration_min").show(truncate=False)
print("### Percentiles mph");          pct_query("mph").show(truncate=False)

# --- Muestras de filas problemáticas (hasta 5 por tipo) ---
cols_show = ["service","pickup_ts","dropoff_ts","trip_distance","total_amount",
             "passenger_count","ratecode_id","payment_type","duration_min","mph","pu_zone","do_zone"]

def show_examples(label, condition):
    print(f"\n### Ejemplos: {label}")
    (df2
     .filter(condition)
     .select(*cols_show)
     .orderBy(F.col("pickup_ts").asc_nulls_last())
     .limit(5)
     .show(truncate=False))

for label, condition in bad.items():
    show_examples(label, condition)
# Out:
# ### Muestra
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 34326)
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py", line 516, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/opt/conda/lib/python3.11/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/opt/conda/lib/python3.11/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/opt/conda/lib/python3.11/socketserver.py", line 755, in __init__
#     self.handle()
#   File "/usr/local/spark/python/pyspark/accumulators.py", line 295, in handle
#     poll(accum_updates)
#   File "/usr/local/spark/python/pyspark/accumulators.py", line 267, in poll
#     if self.rfile in r and func():
#                            ^^^^^^
#   File "/usr/local/spark/python/pyspark/accumulators.py", line 271, in accum_updates
#     num_updates = read_int(self.rfile)
#                   ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/spark/python/pyspark/serializers.py", line 596, in read_int
#     raise EOFError
# EOFError
# ----------------------------------------
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py", line 516, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# ---------------------------------------------------------------------------
# Py4JError                                 Traceback (most recent call last)
# Cell In[10], line 24
#      17 df = (spark.read.format("jdbc")
#      18       .options(**JDBC_OPTS)
#      19       .option("dbtable", base_sql)
#      20       .load())
#      22 print("### Muestra")
#      23 df.select("service","year","month","vendor_id","pickup_ts","dropoff_ts",
# ---> 24           "trip_distance","total_amount","passenger_count","ratecode_id","payment_type").show(5, truncate=False)
#      26 # --- Derivadas útiles ---
#      27 df2 = (
#      28     df
#      29     .withColumn("duration_min", (F.col("dropoff_ts").cast("long") - F.col("pickup_ts").cast("long"))/60.0)
#      30     .withColumn("duration_hr",  F.col("duration_min")/60.0)
#      31     .withColumn("mph", F.when(F.col("duration_hr")>0, F.col("trip_distance")/F.col("duration_hr")))
#      32 )
#
# File /usr/local/spark/python/pyspark/sql/dataframe.py:972, in DataFrame.show(self, n, truncate, vertical)
#     963 except ValueError:
#     964     raise PySparkTypeError(
#     965         error_class="NOT_BOOL",
#     966         message_parameters={
#    (...)
#     969         },
#     970     )
# --> 972 print(self._jdf.showString(n, int_truncate, vertical))
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /usr/local/spark/python/pyspark/errors/exceptions/captured.py:179, in capture_sql_exception.<locals>.deco(*a, **kw)
#     177 def deco(*a: Any, **kw: Any) -> Any:
#     178     try:
# --> 179         return f(*a, **kw)
#     180     except Py4JJavaError as e:
#     181         converted = convert_exception(e.java_exception)
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/protocol.py:334, in get_return_value(answer, gateway_client, target_id, name)
#     330             raise Py4JError(
#     331                 "An error occurred while calling {0}{1}{2}. Trace:\n{3}\n".
#     332                 format(target_id, ".", name, value))
#     333     else:
# --> 334         raise Py4JError(
#     335             "An error occurred while calling {0}{1}{2}".
#     336             format(target_id, ".", name))
#     337 else:
#     338     type = answer[1]
#
# Py4JError: An error occurred while calling o1989.showString
